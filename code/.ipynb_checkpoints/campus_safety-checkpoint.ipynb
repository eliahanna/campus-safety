# %%
import pandas as pd

# %%
file = '../data/oncampusvawa151617.xls'

# %%
data = pd.read_excel(file, index_col = 0)

# %%
data.head()
# Out:
#                                         INSTNM  \
# UNITID_P
# 100654001             Alabama A & M University
# 100663001  University of Alabama at Birmingham
# 100663002  University of Alabama at Birmingham
# 100690001                   Amridge University
# 100706001  University of Alabama in Huntsville
#
#                                        BRANCH  \
# UNITID_P
# 100654001                         Main Campus
# 100663001                         Main Campus
# 100663002  Huntsville Regional Medical Campus
# 100690001                         Main Campus
# 100706001                         Main Campus
#
#                                                      Address        City  \
# UNITID_P
# 100654001                                   4900 MERIDIAN ST      NORMAL
# 100663001  ADMINISTRATION BLDG SUITE 1070, 701 20th Stree...  BIRMINGHAM
# 100663002                             301 Governors Drive SW  Huntsville
# ...
